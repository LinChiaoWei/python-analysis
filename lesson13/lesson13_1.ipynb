# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure
fig = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0,1,2]
Y = [3,4,5]
axes.plot(X,Y,color='green',marker='o',linestyle='dashed',linewidth=2,markersize=12)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1,3,1) #3表示建立1個畫布有3個圖表
axes2 = figure.add_subplot(1,3,2)
axes3 = figure.add_subplot(1,3,3)

axes1.set_title("polt1")
axes2.set_title("polt2")
axes3.set_title("polt3")
plt.show()

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\miniconda\envs\myenv\lib\site-packages (3.2)

# %%
import wget

wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont (1).ttf'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

figure = plt.figure()
axes1 = figure.add_subplot(1,3,1) #3表示建立1個畫布有3個圖表
axes2 = figure.add_subplot(1,3,2)
axes3 = figure.add_subplot(1,3,3)
#無法顯示中文可以下載套件
axes1.set_title("圖表1")
axes2.set_title("圖表2")
axes3.set_title("圖表3")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}
subjects = list(student1.keys()) #dict的實體方法:keys.values.items
stu1_values = list(student1.values()) #轉為list
stu2_values = list(student2.values()) 
subjects, stu1_values, stu2_values#顯示為tuple
# Out:
# (['國文', '英文', '數學', '歷史', '探索'], [78, 80, 92, 75, 85], [90, 75, 98, 65, 75])

# %%
#標準寫法
figure = plt.figure(figsize=(8,5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.',label="學生1")
axes.plot(subjects,stu2_values,marker='o',linestyle='-.',label="學生2")
axes.hlines(85,xmin=-1,xmax=6,color='red',linestyles='--')
x_locations = axes.get_xticks()
y_locations = axes.get_yticks()
#print(axes.get_xticklabels())
#axes.set_xticklabels(['chiness','english','math','history','discover'])
axes.set_xlim(xmin=min(x_locations)-1,xmax=max(x_locations)+1)
axes.set_ylim(ymin=min(y_locations)-10,ymax=max(y_locations)+10)

for x in x_locations:
    axes.annotate(str(stu1_values[x]),(x,stu1_values[x]+1))
    axes.annotate(str(stu2_values[x]),(x,stu2_values[x]+1))
#axes.annotate("註解",(0,80))
axes.legend()
axes.grid(axis='y')
plt.show()
plt.close()

# %%
#標準寫法
figure = plt.figure(figsize=(8,5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.',label="學生1")
axes.plot(subjects,stu2_values,marker='o',linestyle='-.',label="學生2")
print(axes.get_xticks())
print(axes.get_xticklabels())
axes.set_xticklabels(['chiness','english','math','history','discover'])
axes.legend()
plt.show()
plt.close()
# Out:
# [0, 1, 2, 3, 4]
# [Text(0, 0, '國文'), Text(1, 0, '英文'), Text(2, 0, '數學'), Text(3, 0, '歷史'), Text(4, 0, '探索')]
# C:\Users\林巧雅\AppData\Local\Temp\ipykernel_10188\2085143055.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(['chiness','english','math','history','discover'])
